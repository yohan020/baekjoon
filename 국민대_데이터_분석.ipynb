# %% [markdown]
# <a href="https://colab.research.google.com/github/yohan020/baekjoon/blob/main/%EA%B5%AD%EB%AF%BC%EB%8C%80_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv('/content/drive/MyDrive/gukmin_data/train.csv')

# %%
df_train.head()
# Out:
#     item_id  year  month  seq  type   hs4    weight  quantity     value
# 0  DEWLVASR  2022      1  1.0     1  3038   14858.0       0.0   32688.0
# 1  ELQGMQWE  2022      1  1.0     1  2002   62195.0       0.0  110617.0
# 2  AHMDUILJ  2022      1  1.0     1  2102   18426.0       0.0   72766.0
# 3  XIPPENFQ  2022      1  1.0     1  2501   20426.0       0.0   11172.0
# 4  FTSVTTSR  2022      1  1.0     1  2529  248000.0       0.0  143004.0

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10836 entries, 0 to 10835
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item_id   10836 non-null  object
#  1   year      10836 non-null  int64
#  2   month     10836 non-null  int64
#  3   seq       10836 non-null  float64
#  4   type      10836 non-null  int64
#  5   hs4       10836 non-null  int64
#  6   weight    10836 non-null  float64
#  7   quantity  10836 non-null  float64
#  8   value     10836 non-null  float64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 762.0+ KB

# %%
len(df_train['item_id'].unique())
# Out:
# 100

# %%
df_train['year'].unique()
# Out:
# array([2022, 2023, 2024, 2025])

# %%
df_train[(df_train['month']==1) & (df_train['year']==2022)]
# Out:
#       item_id  year  month  seq  type   hs4     weight  quantity      value
# 0    DEWLVASR  2022      1  1.0     1  3038    14858.0       0.0    32688.0
# 1    ELQGMQWE  2022      1  1.0     1  2002    62195.0       0.0   110617.0
# 2    AHMDUILJ  2022      1  1.0     1  2102    18426.0       0.0    72766.0
# 3    XIPPENFQ  2022      1  1.0     1  2501    20426.0       0.0    11172.0
# 4    FTSVTTSR  2022      1  1.0     1  2529   248000.0       0.0   143004.0
# ..        ...   ...    ...  ...   ...   ...        ...       ...        ...
# 232  VMAQSTJE  2022      1  3.0     1  8527     5736.0    7624.0   149766.0
# 233  XIFHSOWQ  2022      1  3.0     1  8708       82.0       0.0     4187.0
# 234  FITUEHWN  2022      1  3.0     1  8714      340.0     244.0     8325.0
# 235  UGEQLMXM  2022      1  3.0     1  8714     1065.0       0.0    64498.0
# 236  BUZIIBYG  2022      1  3.0     1  9403  2507134.0       0.0  6573780.0
#
# [237 rows x 9 columns]

# %%
hs4_df = df_train.groupby(['hs4','year'])[['weight','quantity','value']].sum()

# %%
hs4_df
# Out:
#                weight  quantity        value
# hs4  year
# 1210 2022    407554.0       0.0    6421867.0
#      2023    395332.0       0.0    7120389.0
#      2024    207267.0       0.0    3671103.0
#      2025    121039.0       0.0    1842382.0
# 2002 2022   1971468.0       0.0    3659846.0
# ...               ...       ...          ...
# 9022 2025       469.0      12.0     107818.0
# 9403 2022  69551221.0       0.0  213245740.0
#      2023  66861575.0       0.0  198128867.0
#      2024  77967684.0       0.0  210657740.0
#      2025  44887437.0       0.0  118383440.0
#
# [275 rows x 3 columns]
